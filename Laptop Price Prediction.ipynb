# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/laptop_price.csv",encoding = 'latin')
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.sample(3)
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 113         116      HP        Probook 440            Notebook    14.0
# 362         368  Lenovo  IdeaPad 320-17IKB            Notebook    17.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                         Cpu  \
# 113                           IPS Panel 1366x768  Intel Core i5 8250U 1.6GHz
# 362                                     1600x900  Intel Core i5 7200U 2.5GHz
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  Intel Core i7 6500U 2.5GHz
#
#        Ram                Memory                       Gpu       OpSys  \
# 113    4GB             500GB HDD    Intel UHD Graphics 620  Windows 10
# 362    6GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 940MX  Windows 10
# 1299  16GB             512GB SSD     Intel HD Graphics 520  Windows 10
#
#       Weight  Price_euros
# 113   1.63kg        722.0
# 362    2.8kg        719.0
# 1299   1.3kg       1499.0

# %%
df.drop(columns =['laptop_ID'],inplace = True) #laptopID column removed and assigned a 0 1 2

# %%
df.drop(columns =['Product'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %%
df.isnull().sum() #count the no. of missing values
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (1274, 11)

# %%
df['Price'] = round(df['Price_euros']*89.66).astype('int') #converted currency euros to INR in column Price

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69  120117
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94   80599
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00   51554
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45  227508
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60  161711

# %%
df.drop(columns =['Price_euros'],inplace = True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches             ScreenResolution  \
# 383  Lenovo  Notebook    14.0  IPS Panel Full HD 1920x1080
#
#                             Cpu  Ram     Memory                   Gpu  \
# 383  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Nvidia GeForce 940MX
#
#           OpSys Weight  Price
# 383  Windows 10  1.5kg  98536

# %%
#EDA #Before filtering
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
#Groupby to get the average amount of each brand
df.groupby('Company')['Price'].mean()
# Out:
# Company
# Acer          56796.415842
# Apple        140246.142857
# Asus         101210.741722
# Chuwi         28179.666667
# Dell         107522.474227
# Fujitsu       65362.000000
# Google       150419.333333
# HP            96860.981343
# Huawei       127675.500000
# LG           188196.000000
# Lenovo        98075.612457
# MSI          155013.777778
# Mediacom      26449.714286
# Microsoft    144559.500000
# Razer        300014.857143
# Samsung      126729.222222
# Toshiba      113672.062500
# Vero          19494.250000
# Xiaomi       101626.250000
# Name: Price, dtype: float64

# %%
#Filtering for  only those companies which has repeat more the 10 times in the dataset to reduce the category in the data and assigning back to df
df = df[df.groupby('Company')['Company'].transform('count') > 10]

# %%
df['Company'].value_counts().plot(kind = 'bar') #After filtering
# Out:
# <Axes: xlabel='Company'>

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  120117
# 1        Intel HD Graphics 6000  macOS  1.34kg   80599
# 2         Intel HD Graphics 620  No OS  1.86kg   51554
# 3            AMD Radeon Pro 455  macOS  1.83kg  227508
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg  161711

# %%
df.reset_index(drop = True,inplace = True) #reset index

# %%
sns.barplot(x = 'Company',y = 'Price',data = df)
plt.show()

# %%
df.sample()
# Out:
#     Company   TypeName  Inches                  ScreenResolution  \
# 108    Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                             Cpu  Ram     Memory                           Gpu  \
# 108  Intel Core i7 7560U 2.4GHz  8GB  256GB SSD  Intel Iris Plus Graphics 640
#
#           OpSys  Weight   Price
# 108  Windows 10  1.23kg  123641

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              687
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    636
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.displot(df['Inches'],kde=True) #distribution plot with smooth density curve

# %%
sns.scatterplot(x=df['Inches'],y=df['Price']) #show the scatter plot of laptop price acc to Inches
plt.xticks(rotation=90)
plt.show() #displays the plot

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         257
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 111, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
#I want to fetch the first 3 words i.e Intel Core i5/i7/i3....
#I just want to fetch the Series of AMD i.e E/A/D....
#Wherever i have somtheing like (Intel Celeron Dual Core N3050 1.6GHz/Intel Pentium / Intel Quad ) i want to categorize it as intel CPU

# %%
a = 'Intel Core i5 7200U 2.5GHz'

# %%
a.split()
# Out:
# ['Intel', 'Core', 'i5', '7200U', '2.5GHz']

# %%
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
" ".join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
(lambda a : " ".join(a.split()[0:3]))('Intel Core i5 7200U 2.5GHz')
# Out:
# 'Intel Core i5'

# %%
df['Cpu'] = df['Cpu'].apply(lambda a : " ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           65
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom x5-Z8350           1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  elif text.split()[0] == 'Intel':
    return 'Other Intel Processor'
  else:
    if text[4] == 'E':
      return 'AMD E Series Processor'
    elif text[4] == 'A':
      return 'AMD A Series Processor'
    elif text[4] == 'D':
      return 'AMD D Series Processor'
    elif text[4] == 'F':
      return 'AMD F Series Processor'
    else:
      return 'AMD Ryzen Series'

# %%
fetch_processor(df['Cpu'][5])
# Out:
# 'AMD A Series Processor'

# %%
df['Cpu'] =  df['Cpu'].apply(fetch_processor)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7             493
# Intel Core i5             411
# Intel Core i3             134
# Other Intel Processor     125
# AMD A Series Processor     45
# AMD E Series Processor      9
# AMD Ryzen Series            4
# AMD F Series Processor      2
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company   TypeName  Inches   ScreenResolution            Cpu  Ram  \
# 886      HP  Ultrabook    12.5  Full HD 1920x1080  Intel Core i5  4GB
#
#         Memory                    Gpu       OpSys  Weight   Price
# 886  500GB HDD  Intel HD Graphics 520  Windows 10  1.26kg  141573

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     595
# 4GB     350
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
a = '4GB'

# %%
a.replace("GB","")
# Out:
# '4'

# %%
df['Ram'] = df['Ram'].apply(lambda a : a.replace("GB","")).astype('int')

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#      Company   TypeName  Inches ScreenResolution            Cpu  Ram  \
# 1183   Apple  Ultrabook    11.6         1366x768  Intel Core i5    4
#
#                    Memory                     Gpu     OpSys  Weight  Price
# 1183  256GB Flash Storage  Intel HD Graphics 6000  Mac OS X  1.08kg  85984
